# %% [markdown]
# # [STEP2] ChatGPTによるSQL生成
#
# データベース構造から特定のカラムだけを抽出するSQLを、ChatGPTを用いて生成できるかを検証する。

# %%
# Pythonライブラリインストール
# ※Python 3.10.x　使用推奨
# !python --version
# !pip install python-dotenv
# !pip install --upgrade openai
# !pip install openai[datalib]

# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install plotly
# !pip install scikit-learn
# !pip install sqlalchemy

# %% [markdown]
# ## 環境変数
# supabase接続用URL,APIキーと、openai api接続用のAPIキーを設定します。
# 自身のopenaiアカウントからapi keyを取得してください。
#
# https://platform.openai.com/account/api-keys
#
# supabaseの情報は管理者にお尋ねください。
#
# 下記の例では、.envファイルに変数を書き込んで、JupiterNotebookで読み込む仕様で実装しております。
#
# ※.envファイルの作成が困難、.envファイルから値を読み込めない場合、
# 　os.getenv("◯◯")部分に変数値を直接書き込んでいただいても動作自体には問題ありません。

# %%
# 環境変数
import os
from dotenv import load_dotenv
load_dotenv()

# supabase接続用変数
db_host = os.getenv("DB_HOST")
db_port = os.getenv("DB_PORT")
db_name = os.getenv("DB_NAME")
db_user = os.getenv("DB_USER")
db_pass = os.getenv("DB_PASS")

# OPENAI API KEY
openai_api_key = os.getenv("OPENAI_API_KEY")

print('環境変数読み込み完了')
# Out:
# 環境変数読み込み完了

# %% [markdown]
# # 処理実行
# ## [INPUT] 出力したいカラムリスト
#
# STEP1での出力結果を想定

# %%
# INPUT 出力したいカラムリスト
# STEP1で選定されたカラム（[table name].[column name]）
input_columns = """
structures."name"
structures."acronym"
structures."id"
specimens."structure-id"
experiments."id"
specimens."experiment-id"
projections."experiment-id"
projections."structure-id"
projections."projection-density"
projections."projection-volume"
"""

# データベース構造（テーブル - カラム）
database_structure_information="""
Table: experiments
- id (integer, primary key, unique)
- qc-date (text)
- red-channel (text)
- green-channel (text)
- blue-channel (text)

Table: structures
- id (integer, primary key, unique)
- name (text)
- acronym (text)
- parent-structure-id (integer)
- hemisphere-id (integer)
- st-level (integer)
- superstructures (jsonb)
- substructures (jsonb)
- neighboring-structures (jsonb)

Table: specimens
- id (integer, primary key, unique)
- experiment-id (integer, foreign key referencing experiments.id)
- donor-id (integer)
- sex (text)
- strain (text)
- age (real)
- weight (real)
- structure-id (integer, foreign key referencing structures.id)
- registration-point (text)
- coordinates-ap real null,
- coordinates-dv real null,
- coordinates-ml real null,
- angle (integer)
- injection-materials (text)
- fluor-colors (text)
- injection-method (text)
- days-post-injection (integer)

Table: projections
- id (integer, primary key, unique)
- experiment-id (integer, foreign key referencing experiments.id)
- hemisphere-id (integer)
- structure-id (integer, foreign key referencing structures.id)
- is-injection (boolean)
- normalized-projection-volume (real)
- projection-density (real),
- projection-energy (real)
- projection-intensity (real)
- projection-volume (real)
- volume (real)
"""

# %% [markdown]
# ## OpenAI API (GPT-4)を用いてSQL生成

# %%
import openai
openai.api_key = openai_api_key


def generate_sql(query:str):
    completion = openai.ChatCompletion.create(
      model="gpt-4",
      messages=[
        {"role": "system", "content": "You have a database related with Mouse Brain Connectivity that resource is Allen Brain Atlas API.\n----\n"+database_structure_information},
        {"role": "system", "content": "Return a completion consisted of only SQL"},
        {"role": "user", "content": "Generate SQL for Postgre in order to export columns below \n----\n"+query}
      ],
      temperature=0.1
    )
    return completion.choices[0].message.content

sql = generate_sql(input_columns)

print(sql)
# Out:
# SELECT
#     structures.name,
#     structures.acronym,
#     structures.id AS structure_id,
#     specimens.structure_id AS specimen_structure_id,
#     experiments.id AS experiment_id,
#     specimens.experiment_id AS specimen_experiment_id,
#     projections.experiment_id AS projection_experiment_id,
#     projections.structure_id AS projection_structure_id,
#     projections.projection_density,
#     projections.projection_volume
# FROM
#     structures
# JOIN
#     specimens ON specimens.structure_id = structures.id
# JOIN
#     experiments ON experiments.id = specimens.experiment_id
# JOIN
#     projections ON projections.experiment_id = experiments.id AND projections.structure_id = structures.id;

# %% [markdown]
# ## SQLを適用しデータ出力
#
# カラム名を一部修正

# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy import text
import urllib.parse
from IPython.display import display

fixed_column_names = [
  {
    "before":".structure_id",
    "after":".\"structure-id\""
  },
  {
    "before":".experiment_id",
    "after":".\"experiment-id\""
  },
  {
    "before":".projection_density",
    "after":".\"projection-density\""
  },
  {
    "before":".projection_volume",
    "after":".\"projection-volume\""
  },
  {
    "before":";",
    "after":" LIMIT 50;"
  }
]
sql_fixed = sql
for f in fixed_column_names:
  sql_fixed=sql_fixed.replace(f["before"], f["after"])

print(sql_fixed)


# Connect to the database
connection_config = {
    'user': db_user,
    'password': urllib.parse.quote_plus(db_pass),
    'host': db_host,
    'port': db_port, 
    'database': db_name
}
engine = create_engine('postgresql://{user}:{password}@{host}:{port}/{database}'.format(**connection_config))
with engine.begin() as conn:
    query = text(sql_fixed)
    df = pd.read_sql_query(query, conn)

display(df)
# Out:
# SELECT
#     structures.name,
#     structures.acronym,
#     structures.id AS structure_id,
#     specimens."structure-id" AS specimen_structure_id,
#     experiments.id AS experiment_id,
#     specimens."experiment-id" AS specimen_experiment_id,
#     projections."experiment-id" AS projection_experiment_id,
#     projections."structure-id" AS projection_structure_id,
#     projections."projection-density",
#     projections."projection-volume"
# FROM
#     structures
# JOIN
#     specimens ON specimens."structure-id" = structures.id
# JOIN
#     experiments ON experiments.id = specimens."experiment-id"
# JOIN
#     projections ON projections."experiment-id" = experiments.id AND projections."structure-id" = structures.id LIMIT 50;
#                                              name acronym  structure_id
# 0               Primary somatosensory area, trunk  SSp-tr           361  \
# 1               Primary somatosensory area, trunk  SSp-tr           361
# 2               Primary somatosensory area, trunk  SSp-tr           361
# 3               Primary somatosensory area, trunk  SSp-tr           361
# 4               Primary somatosensory area, trunk  SSp-tr           361
# 5                              Primary motor area     MOp           985
# 6                              Primary motor area     MOp           985
# 7                              Primary motor area     MOp           985
# 8                              Primary motor area     MOp           985
# 9                              Primary motor area     MOp           985
# 10                            Inferior colliculus      IC             4
# 11                            Inferior colliculus      IC             4
# 12                            Inferior colliculus      IC             4
# 13                            Inferior colliculus      IC             4
# 14                            Inferior colliculus      IC             4
# 15                          Medial septal nucleus      MS           564
# 16                          Medial septal nucleus      MS           564
# 17                          Medial septal nucleus      MS           564
# 18                          Medial septal nucleus      MS           564
# 19                          Medial septal nucleus      MS           564
# 20                          Medial septal nucleus      MS           564
# 21  Dorsal part of the lateral geniculate complex     LGd           170
# 22  Dorsal part of the lateral geniculate complex     LGd           170
# 23  Dorsal part of the lateral geniculate complex     LGd           170
# 24  Dorsal part of the lateral geniculate complex     LGd           170
# 25  Dorsal part of the lateral geniculate complex     LGd           170
# 26                       Anteromedial visual area   VISam           394
# 27                       Anteromedial visual area   VISam           394
# 28                       Anteromedial visual area   VISam           394
# 29                       Anteromedial visual area   VISam           394
# 30                       Anteromedial visual area   VISam           394
# 31                             Primary motor area     MOp           985
# 32                             Primary motor area     MOp           985
# 33                             Primary motor area     MOp           985
# 34                             Primary motor area     MOp           985
# 35                             Primary motor area     MOp           985
# 36                        Laterointermediate area   VISli     312782574
# 37                        Laterointermediate area   VISli     312782574
# 38                        Laterointermediate area   VISli     312782574
# 39                        Laterointermediate area   VISli     312782574
# 40                        Laterointermediate area   VISli     312782574
# 41               Substantia nigra, reticular part     SNr           381
# 42               Substantia nigra, reticular part     SNr           381
# 43               Substantia nigra, reticular part     SNr           381
# 44               Substantia nigra, reticular part     SNr           381
# 45               Substantia nigra, reticular part     SNr           381
# 46                                  Postsubiculum    POST          1037
# 47                                  Postsubiculum    POST          1037
# 48                                  Postsubiculum    POST          1037
# 49                                  Postsubiculum    POST          1037
#
#     specimen_structure_id  experiment_id  specimen_experiment_id
# 0                     361      100141495               100141495  \
# 1                     361      100141495               100141495
# 2                     361      100141495               100141495
# 3                     361      100141495               100141495
# 4                     361      100141495               100141495
# 5                     985      100141563               100141563
# 6                     985      100141563               100141563
# 7                     985      100141563               100141563
# 8                     985      100141563               100141563
# 9                     985      100141563               100141563
# 10                      4      100141596               100141596
# 11                      4      100141596               100141596
# 12                      4      100141596               100141596
# 13                      4      100141596               100141596
# 14                      4      100141596               100141596
# 15                    564      100141597               100141597
# 16                    564      100141597               100141597
# 17                    564      100141597               100141597
# 18                    564      100141597               100141597
# 19                    564      100141597               100141597
# 20                    564      100141597               100141597
# 21                    170      100141598               100141598
# 22                    170      100141598               100141598
# 23                    170      100141598               100141598
# 24                    170      100141598               100141598
# 25                    170      100141598               100141598
# 26                    394      100141599               100141599
# 27                    394      100141599               100141599
# 28                    394      100141599               100141599
# 29                    394      100141599               100141599
# 30                    394      100141599               100141599
# 31                    985      100141780               100141780
# 32                    985      100141780               100141780
# 33                    985      100141780               100141780
# 34                    985      100141780               100141780
# 35                    985      100141780               100141780
# 36              312782574      100141796               100141796
# 37              312782574      100141796               100141796
# 38              312782574      100141796               100141796
# 39              312782574      100141796               100141796
# 40              312782574      100141796               100141796
# 41                    381      100141993               100141993
# 42                    381      100141993               100141993
# 43                    381      100141993               100141993
# 44                    381      100141993               100141993
# 45                    381      100141993               100141993
# 46                   1037      100142354               100142354
# 47                   1037      100142354               100142354
# 48                   1037      100142354               100142354
# 49                   1037      100142354               100142354
#
#     projection_experiment_id  projection_structure_id  projection-density
# 0                  100141495                      361            0.999836  \
# 1                  100141495                      361            0.337459
# 2                  100141495                      361            0.056894
# 3                  100141495                      361            0.999836
# 4                  100141495                      361            0.186871
# 5                  100141563                      985            0.998060
# 6                  100141563                      985            0.101209
# 7                  100141563                      985            0.038175
# 8                  100141563                      985            0.998060
# 9                  100141563                      985            0.069309
# 10                 100141596                        4            1.000000
# 11                 100141596                        4            0.519775
# 12                 100141596                        4            0.064659
# 13                 100141596                        4            1.000000
# 14                 100141596                        4            0.281787
# 15                 100141597                      564            0.993758
# 16                 100141597                      564            0.726662
# 17                 100141597                      564            0.998902
# 18                 100141597                      564            0.826841
# 19                 100141597                      564            0.996365
# 20                 100141597                      564            0.776061
# 21                 100141598                      170            0.999073
# 22                 100141598                      170            0.103108
# 23                 100141598                      170            0.000000
# 24                 100141598                      170            0.999073
# 25                 100141598                      170            0.048211
# 26                 100141599                      394            0.998854
# 27                 100141599                      394            0.668406
# 28                 100141599                      394            0.068956
# 29                 100141599                      394            0.998854
# 30                 100141599                      394            0.342826
# 31                 100141780                      985            1.000000
# 32                 100141780                      985            0.358696
# 33                 100141780                      985            0.236414
# 34                 100141780                      985            1.000000
# 35                 100141780                      985            0.296687
# 36                 100141796                312782574            0.156694
# 37                 100141796                312782574            1.000000
# 38                 100141796                312782574            0.848339
# 39                 100141796                312782574            1.000000
# 40                 100141796                312782574            0.441543
# 41                 100141993                      381            0.986285
# 42                 100141993                      381            0.236079
# 43                 100141993                      381            0.000909
# 44                 100141993                      381            0.986285
# 45                 100141993                      381            0.101431
# 46                 100142354                     1037            0.999821
# 47                 100142354                     1037            0.535164
# 48                 100142354                     1037            0.092494
# 49                 100142354                     1037            0.999821
#
#     projection-volume
# 0            0.105739
# 1            0.225061
# 2            0.043961
# 3            0.105739
# 4            0.269023
# 5            0.150013
# 6            0.618095
# 7            0.238877
# 8            0.150013
# 9            0.856972
# 10           0.214794
# 11           1.162120
# 12           0.158453
# 13           0.214794
# 14           1.320580
# 15           0.112810
# 16           0.083815
# 17           0.116529
# 18           0.092775
# 19           0.229339
# 20           0.176590
# 21           0.048451
# 22           0.036055
# 23           0.000000
# 24           0.048451
# 25           0.036055
# 26           0.069312
# 27           0.245643
# 28           0.030127
# 29           0.069312
# 30           0.275770
# 31           0.175181
# 32           2.181680
# 33           1.479340
# 34           0.175181
# 35           3.661020
# 36           0.042505
# 37           0.081317
# 38           0.161138
# 39           0.081317
# 40           0.203643
# 41           0.213580
# 42           0.150589
# 43           0.000777
# 44           0.213580
# 45           0.151366
# 46           0.086186
# 47           0.273701
# 48           0.055278
# 49           0.086186
